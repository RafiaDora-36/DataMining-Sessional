# %%
from sklearn.cluster import KMeans
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Data dictionary 
data =pd.read_csv("kmean_data.csv")
# coversion of data dictionary to data frame
df = pd.DataFrame(data)
df
# Out:
#      x   y
# 0   25  79
# 1   34  51
# 2   22  53
# 3   27  78
# 4   33  59
# 5   33  74
# 6   31  73
# 7   22  57
# 8   35  69
# 9   34  75
# 10  67  51
# 11  54  32
# 12  57  40
# 13  43  47
# 14  50  53
# 15  57  36
# 16  59  35
# 17  52  58
# 18  65  59
# 19  47  50
# 20  49  25
# 21  48  20
# 22  35  14
# 23  33  12
# 24  44  20
# 25  45   5
# 26  38  29
# 27  43  27
# 28  51   8
# 29  46   7

# %%
plt.scatter(df['x'], df['y'])

# %%
km = KMeans(n_clusters=2)
y_predicted = km.fit_predict(df[['x','y']])
df['cluster'] = y_predicted
df
# Out:
#      x   y  cluster
# 0   25  79        1
# 1   34  51        1
# 2   22  53        1
# 3   27  78        1
# 4   33  59        1
# 5   33  74        1
# 6   31  73        1
# 7   22  57        1
# 8   35  69        1
# 9   34  75        1
# 10  67  51        1
# 11  54  32        0
# 12  57  40        0
# 13  43  47        1
# 14  50  53        1
# 15  57  36        0
# 16  59  35        0
# 17  52  58        1
# 18  65  59        1
# 19  47  50        1
# 20  49  25        0
# 21  48  20        0
# 22  35  14        0
# 23  33  12        0
# 24  44  20        0
# 25  45   5        0
# 26  38  29        0
# 27  43  27        0
# 28  51   8        0
# 29  46   7        0

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]

plt.scatter(df1['x'], df1['y'], color='red')
plt.scatter(df2['x'], df2['y'], color='green')


plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
